# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Car Sale.csv')

# %%
df.rename(columns={'Price ($)': 'Price'}, inplace=True)

# %%
df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black  26000  06457-3834
# 1  DoubleÂ Overhead Camshaft         Auto       Black  19000  60504-7114
# ...

# %%
df.shape
# Out:
# (23906, 16)

# %%
df.tail()
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price  Dealer_No   \
# 23901          Overhead Camshaft       Manual         Red  12000  60504-7114
# ...

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price            0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?

# %%
df.groupby('Dealer_Name')['Price'].mean()
# Out:
# Dealer_Name
# Buddy Storbeck's Diesel Service Inc                27217.261563
# C & M Motors Inc                                   28111.755200
# Capitol KIA                                        28189.703822
# Chrysler Plymouth                                  27555.526400
# Chrysler of Tri-Cities                             28123.091054
# Classic Chevy                                      28602.014446
# Clay Johnson Auto Sales                            27816.027113
# Diehl Motor CO Inc                                 27993.929487
# Enterprise Rent A Car                              28312.580800
# Gartner Buick Hyundai Saab                         28247.621019
# Hatfield Volkswagen                                27853.712242
# Iceberg Rentals                                    28522.958533
# McKinney Dodge Chrysler Jeep                       27684.096979
# Motor Vehicle Branch Office                        27956.739617
# ...

# %% [markdown]
# 2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trnds?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
price_var = df.groupby('Company')['Price'].std()

# %%
price_var
# Out:
# Company
# Acura          8183.046414
# Audi          12904.243867
# BMW           15065.578723
# Buick         17142.232626
# Cadillac      19517.120220
# Chevrolet     13311.063223
# Chrysler      11583.286811
# Dodge         11181.678786
# Ford          15849.090227
# Honda         11148.629062
# Hyundai        3485.982649
# Infiniti      13696.332844
# Jaguar        10222.531533
# Jeep           9459.834418
# Lexus         17852.923492
# Lincoln       19658.050211
# Mercedes-B    15722.807459
# Mercury       16445.172195
# Mitsubishi    11671.343035
# Nissan        16214.264017
# Oldsmobile    15711.345857
# Plymouth      19065.997338
# Pontiac       14348.963592
# Porsche        5261.839206
# Saab          19653.740089
# Saturn        15990.223671
# Subaru        12920.771620
# Toyota        15367.131714
# Volkswagen    12527.124011
# Volvo         12933.790185
# Name: Price, dtype: float64

# %%
price_var.max()
# Out:
# 19658.050211265567

# %%
price = df['Price']

# %%
price_var.idxmax()
# Out:
# 'Lincoln'

# %%
sns.distplot(price_var)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# 3. what is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
Iqr = df.groupby('Transmission')['Price'].quantile(0.75) - df.groupby('Transmission')['Price'].quantile(0.25)

# %%
Iqr
# Out:
# Transmission
# Auto      16500.0
# Manual    17000.0
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Price', hue='Transmission', palette='rainbow', kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 4. What is the distribution of car prices across different regions?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
sns.boxplot(data=df, x='Dealer_Region', y='Price', palette='Set3')
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('Dealer_Region')['Price'].describe()
# Out:
#                 count          mean           std     min      25%      50%  \
# Dealer_Region
# Aurora         3129.0  28329.300735  15025.653685  9000.0  18001.0  23000.0
# Austin         4135.0  28341.603628  14903.884549  9000.0  18001.0  23801.0
# Greenville     3128.0  28180.819054  15101.538328  1200.0  18001.0  22500.0
# Janesville     3821.0  27833.350955  14344.995638  4300.0  18001.0  23000.0
# Middletown     3128.0  27856.338875  14619.842395  1700.0  18000.0  22750.0
# Pasco          3131.0  28119.039923  14659.315941  9000.0  18500.5  23000.0
# Scottsdale     3433.0  27954.958928  14902.916820  1450.0  18000.0  22600.0
#
#                    75%      max
# Dealer_Region
# Aurora         35000.0  85800.0
# Austin         35001.0  85601.0
# Greenville     34500.0  85200.0
# Janesville     34000.0  85400.0
# Middletown     34000.0  85300.0
# Pasco          34000.0  85600.0
# Scottsdale     33500.0  85001.0

# %% [markdown]
# 5. What is the distribution of cars based on body styles?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
sns.countplot(data=df, x='Body Style', palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
df.Model.unique()
# Out:
# array(['Expedition', 'Durango', 'Eldorado', 'Celica', 'TL', 'Diamante',
#        'Corolla', 'Galant', 'Malibu', 'Escort', 'RL', 'Pathfinder',
#        'Grand Marquis', '323i', 'Sebring Coupe', 'Forester', 'Accent',
#        'Land Cruiser', 'Accord', '4Runner', 'I30', 'A4', 'Carrera Cabrio',
#        'Jetta', 'Viper', 'Regal', 'LHS', 'LW', '3000GT', 'SLK230',
#        'Civic', 'S-Type', 'S40', 'Mountaineer', 'Park Avenue',
#        'Montero Sport', 'Sentra', 'S80', 'Lumina', 'Bonneville',
#        'C-Class', 'Altima', 'DeVille', 'Stratus', 'Cougar', 'SW', 'C70',
#        'SLK', 'Tacoma', 'M-Class', 'A6', 'Intrepid', 'Sienna', 'Eclipse',
#        'Contour', 'Town car', 'Focus', 'Mustang', 'Cutlass', 'Corvette',
#        'Impala', 'Cabrio', 'Dakota', '300M', '328i', 'Bravada', 'Maxima',
#        'Ram Pickup', 'Concorde', 'V70', 'Quest', 'ES300', 'SL-Class',
#        'Explorer', 'Prizm', 'Camaro', 'Outback', 'Taurus', 'Cavalier',
# ...

# %%
df['Body Style'].value_counts()
# Out:
# Body Style
# SUV          6374
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2970
# Name: count, dtype: int64

# %% [markdown]
# 6. How does the average selling price of cars vary by customer gender and annual income?

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
average = df.groupby('Price').agg({'Gender': 'count', 'Annual Income': 'mean'})

# %%
average
# Out:
#        Gender  Annual Income
# Price
# 1200        1        13500.0
# 1450        1      1955000.0
# 1700        1        13500.0
# 2200        1        13500.0
# 4200        1       680000.0
# ...       ...            ...
# 85400       1      1414000.0
# 85500       2       841250.0
# 85600       2      1181000.0
# 85601       1      5046000.0
# 85800       1      1388000.0
#
# [870 rows x 2 columns]

# %% [markdown]
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?

# %%
df.groupby('Dealer_Region')['Price'].describe()
# Out:
#                 count          mean           std     min      25%      50%  \
# Dealer_Region
# Aurora         3129.0  28329.300735  15025.653685  9000.0  18001.0  23000.0
# Austin         4135.0  28341.603628  14903.884549  9000.0  18001.0  23801.0
# Greenville     3128.0  28180.819054  15101.538328  1200.0  18001.0  22500.0
# Janesville     3821.0  27833.350955  14344.995638  4300.0  18001.0  23000.0
# Middletown     3128.0  27856.338875  14619.842395  1700.0  18000.0  22750.0
# Pasco          3131.0  28119.039923  14659.315941  9000.0  18500.5  23000.0
# Scottsdale     3433.0  27954.958928  14902.916820  1450.0  18000.0  22600.0
#
#                    75%      max
# Dealer_Region
# Aurora         35000.0  85800.0
# Austin         35001.0  85601.0
# Greenville     34500.0  85200.0
# Janesville     34000.0  85400.0
# Middletown     34000.0  85300.0
# Pasco          34000.0  85600.0
# Scottsdale     33500.0  85001.0

# %% [markdown]
# 8. How does the average car price differ between cars with different engine sizes?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
df.groupby('Engine')['Price'].mean()
# Out:
# Engine
# DoubleÂ Overhead Camshaft    28247.193317
# Overhead Camshaft            27914.710631
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Price', hue='Engine', palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 9. How do car prices vary based on the customer's annual income bracket?

# %%
bins = [0, 50000, 100000, float('inf')]  # Income brackets
labels = ['Low Income', 'Medium Income', 'High Income']
df['Income Bracket'] = pd.cut(df['Annual Income'], bins=bins, labels=labels)

# %%
avg_price_by_income = df.groupby('Income Bracket')['Price'].mean()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=avg_price_by_income.index, y=avg_price_by_income.values, palette='coolwarm')
plt.title('Average Car Price by Annual Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Average Car Price ($)')
plt.show()

# %% [markdown]
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
top_5_models = df.groupby('Model').size().sort_values(ascending=False).head()

# %%
top_5_model_data = df[df['Model'].isin(top_5_models.index)]

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Model', y='Price', data=top_5_model_data, palette='coolwarm')
plt.xticks(rotation=90)
plt.title('Price Distribution of Top 5 Car Models')
plt.xlabel('Car Model')
plt.ylabel('Price ($)')
plt.show()

# %%
#insight:- these are the top 5 models with the higest number of sales, Top model is Jetta

# %% [markdown]
# 11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?

# %%
engine = df.groupby('Engine').agg({'Color' : 'count', 'Price' : 'mean'})

# %%
engine
# Out:
#                            Color         Price
# Engine
# DoubleÂ Overhead Camshaft  12570  28247.193317
# Overhead Camshaft          11335  27914.710631

# %%
plt.figure(figsize=(10,6))
# Pass the original DataFrame 'df' to the 'data' parameter
sns.barplot(x='Engine', y='Price', hue='Color', data=df, palette='coolwarm')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 12. Is there any seasonal trend in car sales based on the data of sale?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
df.drop('Date', axis = 1, inplace = True)

# %%
monthly_sales = df.groupby('Month').size()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker='o', color='b')
plt.title('Monthly Car Sales Trend')
plt.xlabel('Month')
plt.ylabel('Number of Sales')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
#insights:- yeah there is seasonal trends in car sales based on the monthly sales, in this line plot we can see most cars are sale in the Dec,Nov and Sept month

# %% [markdown]
# 13. How does the car price distribution change when considering different combinations of body style ad transmission type?

# %%
df['Body_Transmission'] = df['Body Style'] + ' - ' + df['Transmission']

# %%
sns.violinplot(data=df, x='Body_Transmission', y='Price', palette='rainbow')
plt.title('Car Price Distribution by Body Style and Transmission Type')
plt.xlabel('Body Style - Transmission Type')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 14. What is the correlation between car Price, Engine Size and annual income of customers, and do these features interact?

# %%
df['Engine'] = df['Engine'].str.replace('Â\xa0', ' ', regex=False)

# %%
df['Engine'] = df['Engine'].str.replace(' ', '')

# %%
df.Engine = df.Engine.map({'DoubleOverheadCamshaft' : 1, 'OverheadCamshaft' : 0})

# %%
numeric = df.select_dtypes(include = 'number')

# %%
numeric = df[['Engine','Price','Annual Income']]

# %%
sns.heatmap(numeric.corr(), cmap = 'rainbow', annot = True, vmin = -1, vmax = 1)
plt.title('Correlation Matrix: Price, Engine Size, and Annual Income')
plt.tight_layout()
plt.show()

# %% [markdown]
# 15. How does the average car price vary across different car models and engine types?

# %%
avg_price = df.groupby(['Model', 'Engine'])['Price'].mean().reset_index()

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=avg_price, x='Model', y='Price', hue='Engine', palette='coolwarm')
plt.title('Average Car Price by Model and Engine Type')
plt.xlabel('Car Model')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=90)
plt.legend(title='Engine Type')
plt.tight_layout()
plt.show()
