# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.drop('name', axis = 1, inplace = True)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
sns.boxplot(df['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
df['horsepower'].median()
# Out:
# 93.5

# %%
df['horsepower'].fillna(df['horsepower'].median(), inplace = True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.origin.value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
#data encoding

# %%
df.origin = df.origin.map({'usa' : 1, 'japan':2 , 'europe': 3})

# %%
df.origin.value_counts()
# Out:
# origin
# 1    249
# 2     79
# 3     70
# Name: count, dtype: int64

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
plt.pie(df.origin.value_counts(), labels = ['usa', 'japan', 'europe'], autopct = '%.2f', shadow = True, explode = [0.07,0.04, 0], colors = ['lightcoral','coral','green'], startangle = 90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 25.0 KB

# %%
#Seperate into x and y

# %%
x = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
#train-test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
X_train.shape
# Out:
# (318, 7)

# %%
#Simple linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-0.2165378 ,  0.01987994, -0.01270482, -0.0071647 ,  0.09047637,
#         0.84604207,  1.42800007])

# %%
for i, col_name in enumerate(X_train.columns):
    print('The coefficient for {} is {}'.format(col_name, model.coef_[i]))
# Out:
# The coefficient for cylinders is -0.2165378021683337
# The coefficient for displacement is 0.019879936208875106
# The coefficient for horsepower is -0.012704816241841405
# The coefficient for weight is -0.007164698157663281
# The coefficient for acceleration is 0.0904763671599933
# The coefficient for model_year is 0.8460420672591424
# The coefficient for origin is 1.4280000651600893

# %%
#Observations:- Coefficients are retatively smaller, if one independent variable changes
#There will be not much difference in prediction
#This is sometime called as smoother

#These features might not be contributing in model training

# %%
from sklearn.metrics import r2_score

# %%
y_pred_linear = model.predict(X_test)

# %%
r2_linear = r2_score(Y_test, y_pred_linear)

# %%
print(f"The r2 score for linear model is {r2_linear}")
# Out:
# The r2 score for linear model is 0.856301245145641

# %%
#Regularized Model
#1. Ridge Regression
#in  Practical implementation lambda is alpha

# %%
from sklearn.linear_model import Ridge

# %%
Ridge_Regression_model = Ridge(alpha = 0.2)

# %%
Ridge_Regression_model
# Out:
# Ridge(alpha=0.2)

# %%
Ridge_Regression_model.fit(X_train, Y_train)
# Out:
# Ridge(alpha=0.2)

# %%
for i, col_name in enumerate(X_train.columns):
    print('The coefficient for {} is {}'.format(col_name, Ridge_Regression_model.coef_[i]))
# Out:
# The coefficient for cylinders is -0.2157694601812172
# The coefficient for displacement is 0.01984453419448628
# The coefficient for horsepower is -0.012689849494409948
# The coefficient for weight is -0.0071641593192748945
# The coefficient for acceleration is 0.09043845409324902
# The coefficient for model_year is 0.8459074296535263
# The coefficient for origin is 1.4253406022796973

# %%
#For ridge regression evaluation
y_pred_ridge = Ridge_Regression_model.predict(X_test)
r2_ridge = r2_score(Y_test, y_pred_ridge)

# %%
print(f"The r2 score for ridge model is {r2_ridge}")
# Out:
# The r2 score for ridge model is 0.8563040538546514

# %%
#observations:- We don't see much variations in coeff of ridge regression as compared to Linear Regression

# %%
from sklearn.linear_model import Lasso

# %%
Lasso_Regeession_model = Lasso(alpha = 0.2)

# %%
Lasso_Regeession_model
# Out:
# Lasso(alpha=0.2)

# %%
Lasso_Regeession_model.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.2)

# %%
Lasso_pred = Lasso_Regeession_model.predict(X_test)

# %%
for i, col_name in enumerate(X_train.columns):
    print('The coefficient for {} is {}'.format(col_name, Lasso_Regeession_model.coef_[i]))
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.010120211485857619
# The coefficient for horsepower is -0.013065120375229493
# The coefficient for weight is -0.006867464903759185
# The coefficient for acceleration is 0.02711591209318087
# The coefficient for model_year is 0.8070901281873868
# The coefficient for origin is 0.8114674881097399

# %%
#Three features coefficent is 0, Lasso helps in feature selection

# %%
r2_score_Lasso = r2_score(Y_test, Lasso_pred)

# %%
print(f'The r2 score for Lasso model is {r2_score_Lasso}')
# Out:
# The r2 score for Lasso model is 0.8541261343761706

# %%
#ELastic Net
from sklearn.linear_model import ElasticNet

# %%
Elastic_Net_model = ElasticNet(alpha = 0.2, l1_ratio = 0.5)
Elastic_Net_model.fit(X_train, Y_train)
# Out:
# ElasticNet(alpha=0.2)

# %%
for i, col_name in enumerate(X_train.columns):
    print('The coefficient for {} is {}'.format(col_name, Elastic_Net_model.coef_[i]))
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.011007331633864225
# The coefficient for horsepower is -0.011498899824748136
# The coefficient for weight is -0.006963476335361719
# The coefficient for acceleration is 0.05497581653357263
# The coefficient for model_year is 0.8108268573681062
# The coefficient for origin is 0.8594802474655244

# %%
r2_score_elastic_net = r2_score(Y_test, Elastic_Net_model.predict(X_test))

# %%
print(f'The r2 score for Elastic Net model is {r2_score_elastic_net}')
# Out:
# The r2 score for Elastic Net model is 0.8544370269278475

# %%
#Regularization with Cross Validation

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv = LassoCV(cv = 5, verbose = 2)

# %%
lasso_cv.fit(X_train, Y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# ...

# %%
y_pred = lasso_cv.predict(X_test)

# %%
r2_score_lasso_cv = r2_score(Y_test, y_pred)

# %%
print(f'The r2 score for Lasso CV model is {r2_score_lasso_cv}')
# Out:
# The r2 score for Lasso CV model is 0.8410032034906063

# %%
from sklearn.linear_model import RidgeCV

# %%
ridge_cv_model = RidgeCV(cv = 5)

# %%
ridge_cv_model.fit(X_train, Y_train)
# Out:
# RidgeCV(cv=5)

# %%
y_pred = ridge_cv_model.predict(X_test)

# %%
r2_score(Y_test, y_pred)
# Out:
# 0.8563494248817896

# %%
ridge_cv_model.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
from sklearn.linear_model import ElasticNetCV

# %%
Elastic_Net_CV_model = ElasticNetCV(cv = 5,verbose= 2)

# %%
Elastic_Net_CV_model.fit(X_train, Y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# ...

# %%
Elastic_Net_CV_model.get_params()
# Out:
# {'alphas': None,
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'l1_ratio': 0.5,
#  'max_iter': 1000,
#  'n_alphas': 100,
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': 2}

# %%
y_pred = Elastic_Net_CV_model.predict(X_test)

# %%
r2_score(Y_test, y_pred)
# Out:
# 0.8269714661183815
